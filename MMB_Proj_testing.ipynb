# %% [markdown]
# # Project Testing

# %% [markdown]
# ## Imports

# %%
from IPython.core.display_functions import display
from scipy.stats import chi2


from models.logit_lmpc12_model0 import results as res_mod0
from models.logit_lmpc12_model1 import results as res_mod1
from models.logit_lmpc12_model2 import results as res_mod2
from models.logit_lmpc12_model2bis import results as res_mod2bis
from models.logit_lmpc12_model3 import results as res_mod3
from models.logit_lmpc12_model4 import nests, nests_cross

from models.logit_lmpc12_model3 import V_boxcox as V
from models.logit_lmpc12_model3 import chosen_alternative as choice
import biogeme.biogeme as bio

from biogeme.models import lognested, logcnl
from models.logit_lmpc12_model3 import database

# %% [markdown]
# Informations about the data [here](https://transp-or.epfl.ch/documents/technicalReports/CS_LPMC.pdf).

# %% [markdown]
# ## Base Model (Model 0)

# %%
print(res_mod0.print_general_statistics())
# Out:
# Number of estimated parameters:	5
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-4682.809
# Final log likelihood:	-4682.809
# Likelihood ratio test for the init. model:	-0
# Rho-square for the init. model:	0
# Rho-square-bar for the init. model:	-0.00107
# Akaike Information Criterion:	9375.618
# Bayesian Information Criterion:	9408.204
# Final gradient norm:	6.8872E-03
# Nbr of threads:	4

# %%
display(res_mod0.get_estimated_parameters())
# Out:
#                      Value  Rob. Std err  Rob. t-test  Rob. p-value
# beta_fare        -0.218834      0.016079   -13.609556  0.000000e+00
# beta_travel_time -4.912425      0.196876   -24.951855  0.000000e+00
# constant_2       -3.730635      0.109509   -34.066917  0.000000e+00
# constant_3       -0.330061      0.055250    -5.973956  2.315689e-09
# constant_4       -1.076768      0.080741   -13.336046  0.000000e+00

# %% [markdown]
# ## Alternative Specific Constant Model (Model 1)

# %%
print(res_mod1.print_general_statistics())
# Out:
# Number of estimated parameters:	8
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-4238.158
# Final log likelihood:	-4238.158
# Likelihood ratio test for the init. model:	-0
# Rho-square for the init. model:	0
# Rho-square-bar for the init. model:	-0.00189
# Akaike Information Criterion:	8492.315
# Bayesian Information Criterion:	8544.453
# Final gradient norm:	5.0353E-02
# Nbr of threads:	4

# %%
display(res_mod1.get_estimated_parameters())
# Out:
#                        Value  Rob. Std err  Rob. t-test  Rob. p-value
# beta_fare          -0.219859      0.019544   -11.249155           0.0
# beta_travel_time_1 -8.785093      0.388633   -22.605099           0.0
# beta_travel_time_2 -6.713728      0.611132   -10.985725           0.0
# beta_travel_time_3 -3.176253      0.247091   -12.854585           0.0
# beta_travel_time_4 -6.527874      0.399928   -16.322640           0.0
# constant_2         -4.545080      0.202824   -22.408959           0.0
# constant_3         -2.525913      0.131743   -19.173003           0.0
# constant_4         -2.007088      0.128388   -15.632957           0.0

# %% [markdown]
# ## Socioeconomic Model (Model 2)

# %% [markdown]
# ### Purpose of the Trip Model

# %%
print(res_mod2.print_general_statistics())
# Out:
# Number of estimated parameters:	24
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-4160.081
# Final log likelihood:	-4160.081
# Likelihood ratio test for the init. model:	-0
# Rho-square for the init. model:	0
# Rho-square-bar for the init. model:	-0.00577
# Akaike Information Criterion:	8368.163
# Bayesian Information Criterion:	8524.575
# Final gradient norm:	3.8961E-02
# Nbr of threads:	4

# %%
display(res_mod2.get_estimated_parameters())
# Out:
#                                             Value  ...  Rob. p-value
# beta_fare                               -0.230220  ...  0.000000e+00
# beta_travel_time                        -7.481313  ...  0.000000e+00
# beta_travel_time_2                      -5.663439  ...  5.728751e-14
# beta_travel_time_2_employers business    0.178688  ...  8.894381e-01
# beta_travel_time_2_home-based education -6.299001  ...  5.001880e-03
# beta_travel_time_2_home-based other     -3.706819  ...  6.816801e-04
# beta_travel_time_2_non-homebased other  -6.747271  ...  4.471783e-04
# beta_travel_time_3                      -2.717274  ...  2.497744e-10
# beta_travel_time_3_employers business    1.017722  ...  1.763025e-01
# beta_travel_time_3_home-based education -0.199018  ...  8.253689e-01
# beta_travel_time_3_home-based other     -1.462552  ...  1.226671e-02
# beta_travel_time_3_non-homebased other  -1.245929  ...  1.085373e-01
# beta_travel_time_4                      -6.567252  ...  0.000000e+00
# beta_travel_time_4_employers business    2.794058  ...  2.413143e-02
# beta_travel_time_4_home-based education -1.468617  ...  4.573780e-01
# beta_travel_time_4_home-based other     -1.027031  ...  3.099688e-01
# beta_travel_time_4_non-homebased other   0.118436  ...  9.219106e-01
# beta_travel_time_employers business     -2.646631  ...  5.187217e-03
# beta_travel_time_home-based education   -1.263506  ...  9.870548e-02
# beta_travel_time_home-based other       -2.324890  ...  1.813193e-05
# beta_travel_time_non-homebased other    -1.267851  ...  5.922798e-02
# constant_2                              -4.309282  ...  0.000000e+00
# constant_3                              -2.556251  ...  0.000000e+00
# constant_4                              -2.097902  ...  0.000000e+00
#
# [24 rows x 4 columns]

# %% [markdown]
# ### Gender Model

# %%
print(res_mod2bis.print_general_statistics())
# Out:
# Number of estimated parameters:	11
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-4238.158
# Final log likelihood:	-4238.158
# Likelihood ratio test for the init. model:	-0
# Rho-square for the init. model:	0
# Rho-square-bar for the init. model:	-0.0026
# Akaike Information Criterion:	8498.315
# Bayesian Information Criterion:	8570.004
# Final gradient norm:	5.0443E-02
# Nbr of threads:	4

# %%
display(res_mod2bis.get_estimated_parameters())
# Out:
#                        Value  Rob. Std err    Rob. t-test  Rob. p-value
# beta_fare          -0.219859  1.954445e-02  -1.124916e+01           0.0
# beta_travel_time   -8.785093  3.886332e-01  -2.260510e+01           0.0
# beta_travel_time_2 -6.713728  6.111319e-01  -1.098573e+01           0.0
# beta_travel_time_3 -3.176253  2.470911e-01  -1.285458e+01           0.0
# beta_travel_time_4 -6.527874  3.999276e-01  -1.632264e+01           0.0
# constant_2         -4.545080  2.028242e-01  -2.240896e+01           0.0
# constant_2_other    0.000000  9.236521e-17   0.000000e+00           1.0
# constant_3         -2.525913  1.317432e-01  -1.917300e+01           0.0
# constant_3_other    0.000000  0.000000e+00  1.797693e+308           0.0
# constant_4         -2.007088  1.283883e-01  -1.563296e+01           0.0
# constant_4_other    0.000000  0.000000e+00  1.797693e+308           0.0

# %% [markdown]
# ## Box Cox Model (Model 3)

# %%
print(res_mod3.print_general_statistics())
# Out:
# Number of estimated parameters:	25
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-4137.754
# Final log likelihood:	-4137.754
# Likelihood ratio test for the init. model:	-0
# Rho-square for the init. model:	0
# Rho-square-bar for the init. model:	-0.00604
# Akaike Information Criterion:	8325.509
# Bayesian Information Criterion:	8488.439
# Final gradient norm:	3.6388E-02
# Nbr of threads:	4

# %%
display(res_mod3.get_estimated_parameters())
# Out:
#                                              Value  ...  Rob. p-value
# beta_fare                                -0.212246  ...      0.000000
# beta_travel_time                         -8.772665  ...      0.000000
# beta_travel_time_2                       -5.595616  ...      0.000000
# beta_travel_time_2_employers business     0.823689  ...      0.107480
# beta_travel_time_2_home-based education   1.597105  ...      0.000135
# beta_travel_time_2_home-based other       0.660730  ...      0.031807
# beta_travel_time_2_non-homebased other    0.948577  ...      0.019289
# beta_travel_time_3                       -3.362203  ...      0.000000
# beta_travel_time_3_employers business     1.060805  ...      0.043947
# beta_travel_time_3_home-based education   1.084135  ...      0.007226
# beta_travel_time_3_home-based other       0.351322  ...      0.274899
# beta_travel_time_3_non-homebased other    0.687741  ...      0.054187
# beta_travel_time_4                       -4.356266  ...      0.000000
# beta_travel_time_4_employers business     0.167959  ...      0.642982
# beta_travel_time_4_home-based education   0.871971  ...      0.002786
# beta_travel_time_4_home-based other      -0.219522  ...      0.357241
# beta_travel_time_4_non-homebased other   -0.358502  ...      0.183701
# beta_travel_time_employers business      -5.210145  ...      0.000527
# beta_travel_time_home-based education    -4.048493  ...      0.000394
# beta_travel_time_home-based other        -1.778928  ...      0.025709
# beta_travel_time_non-homebased other     -1.024647  ...      0.278280
# constant_2                              -12.235584  ...      0.000000
# constant_3                               -7.002930  ...      0.000000
# constant_4                               -9.229125  ...      0.000000
# lambda_boxcox                             0.521976  ...      0.000000
#
# [25 rows x 4 columns]

# %% [markdown]
# ## Nested Model (Model 4)

# %%
logprob_nested = lognested(V, None,nests, choice)
biogeme_nested = bio.BIOGEME(database, logprob_nested)
biogeme_nested.modelName = 'nested_model'
results_nested = biogeme_nested.estimate(recycle=False)
print(results_nested.print_general_statistics())
# Out:
# Number of estimated parameters:	26
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-4127.034
# Final log likelihood:	-4127.034
# Likelihood ratio test for the init. model:	-0
# Rho-square for the init. model:	0
# Rho-square-bar for the init. model:	-0.0063
# Akaike Information Criterion:	8306.067
# Bayesian Information Criterion:	8475.514
# Final gradient norm:	1.2779E-01
# Nbr of threads:	4

# %%
display(results_nested.get_estimated_parameters())
# Out:
#                                             Value  ...  Rob. p-value
# beta_fare                               -0.082532  ...  8.969965e-03
# beta_travel_time                        -7.568146  ...  0.000000e+00
# beta_travel_time_2                      -2.904733  ...  1.788183e-05
# beta_travel_time_2_employers business    0.389533  ...  2.699597e-01
# beta_travel_time_2_home-based education  1.052087  ...  2.413102e-03
# beta_travel_time_2_home-based other      0.516560  ...  1.313163e-02
# beta_travel_time_2_non-homebased other   0.751379  ...  1.084407e-02
# beta_travel_time_3                      -1.216800  ...  2.197140e-02
# beta_travel_time_3_employers business    0.308185  ...  2.946577e-01
# beta_travel_time_3_home-based education  0.466216  ...  1.057973e-01
# beta_travel_time_3_home-based other     -0.097994  ...  5.739096e-01
# beta_travel_time_3_non-homebased other   0.122383  ...  5.661637e-01
# beta_travel_time_4                      -1.477257  ...  2.146446e-02
# beta_travel_time_4_employers business   -0.010205  ...  9.488071e-01
# beta_travel_time_4_home-based education  0.361463  ...  8.677099e-02
# beta_travel_time_4_home-based other     -0.229293  ...  3.125597e-02
# beta_travel_time_4_non-homebased other  -0.221062  ...  1.171709e-01
# beta_travel_time_employers business     -3.827319  ...  7.446440e-04
# beta_travel_time_home-based education   -2.822803  ...  4.231398e-03
# beta_travel_time_home-based other       -1.515806  ...  1.140506e-02
# beta_travel_time_non-homebased other    -0.761503  ...  3.120301e-01
# constant_2                              -9.016659  ...  0.000000e+00
# constant_3                              -4.342430  ...  1.491728e-08
# constant_4                              -5.198353  ...  1.359606e-06
# lambda_boxcox                            0.326480  ...  2.630917e-05
# mu_motorized                             2.492381  ...  3.437580e-03
#
# [26 rows x 4 columns]

# %% [markdown]
# ## Cross Nested Model (Model 4)

# %%
logprob_cnl = logcnl(V, None ,nests_cross, choice)
biogeme_cnl = bio.BIOGEME(database, logprob_cnl)
biogeme_cnl.modelName = 'cnl'
results_cross = biogeme_cnl.estimate(recycle=False)
print(results_cross.print_general_statistics())
# Out:
# Number of estimated parameters:	28
# Number of free parameters:	27
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-4125.877
# Final log likelihood:	-4125.877
# Likelihood ratio test for the init. model:	-0
# Rho-square for the init. model:	0
# Rho-square-bar for the init. model:	-0.00679
# Akaike Information Criterion:	8307.753
# Bayesian Information Criterion:	8490.235
# Final gradient norm:	2.8437E+01
# Nbr of threads:	4

# %%
display(results_cross.get_estimated_parameters())
# Out:
#                                             Value  ...  Rob. p-value
# alpha_car_motorized                      0.818492  ...  8.277137e-01
# beta_fare                               -0.098793  ...  7.802415e-01
# beta_travel_time                        -7.684334  ...  5.653305e-01
# beta_travel_time_2                      -3.304270  ...  7.078431e-01
# beta_travel_time_2_employers business    0.461366  ...  7.847576e-01
# beta_travel_time_2_home-based education  1.146079  ...  6.975224e-02
# beta_travel_time_2_home-based other      0.529532  ...  7.172096e-01
# beta_travel_time_2_non-homebased other   0.797137  ...  7.042219e-01
# beta_travel_time_3                      -1.441571  ...  7.621287e-01
# beta_travel_time_3_employers business    0.409648  ...  8.528545e-01
# beta_travel_time_3_home-based education  0.538650  ...  7.827533e-01
# beta_travel_time_3_home-based other     -0.093791  ...  9.147425e-01
# beta_travel_time_3_non-homebased other   0.158359  ...  9.146898e-01
# beta_travel_time_4                      -1.840326  ...  8.314709e-01
# beta_travel_time_4_employers business    0.017642  ...  9.820531e-01
# beta_travel_time_4_home-based education  0.417759  ...  7.770199e-01
# beta_travel_time_4_home-based other     -0.254551  ...  7.567558e-02
# beta_travel_time_4_non-homebased other  -0.241579  ...  2.080073e-01
# beta_travel_time_employers business     -4.005921  ...  1.171211e-01
# beta_travel_time_home-based education   -2.932373  ...  8.029955e-03
# beta_travel_time_home-based other       -1.469268  ...  6.546322e-01
# beta_travel_time_non-homebased other    -0.772149  ...  3.356189e-01
# constant_2                              -9.378589  ...  3.242060e-02
# constant_3                              -4.638053  ...  1.807465e-11
# constant_4                              -5.631694  ...  1.282945e-01
# lambda_boxcox                            0.391893  ...  7.867320e-01
# mu_motorized                             2.455051  ...  3.103278e-03
# mu_private                               1.000000  ...  8.074398e-01
#
# [28 rows x 5 columns]

# %% [markdown]
# ## Model Comparison with statistical tests

# %%
stat_mod0 = res_mod0.get_general_statistics()
stat_mod1 = res_mod1.get_general_statistics()
stat_mod2 = res_mod2.get_general_statistics()
stat_mod2bis = res_mod2bis.get_general_statistics()
stat_mod3 = res_mod3.get_general_statistics()
stat_nested = results_nested.get_general_statistics()
stat_cross = results_cross.get_general_statistics()

# model 0
log_mod0 = stat_mod0.get("Final log likelihood")[0]
num_param_mod0 = stat_mod0.get("Number of estimated parameters")[0]

# model 1
log_mod1 = stat_mod1.get("Final log likelihood")[0]
num_param_mod1 = stat_mod1.get("Number of estimated parameters")[0]

# model 2
log_mod2= stat_mod2.get("Final log likelihood")[0]
num_param_mod2 = stat_mod2.get("Number of estimated parameters")[0]

# model 2 bis
log_mod2bis = stat_mod2bis.get("Final log likelihood")[0]
num_param_mod2bis = stat_mod2bis.get("Number of estimated parameters")[0]

# model 3
log_mod3 = stat_mod3.get("Final log likelihood")[0]
num_param_mod3= stat_mod3.get("Number of estimated parameters")[0]

# model nested
log_nested = stat_nested.get("Final log likelihood")[0]
num_param_nested = stat_nested.get("Number of estimated parameters")[0]

# model cross-nested
log_cross = stat_cross.get("Final log likelihood")[0]
num_param_cross = stat_cross.get("Number of estimated parameters")[0]

# %%
# Model statistics (replace these with actual stats from your data)
models = {
    "mod0": {"log_likelihood": log_mod0, "num_parameters": num_param_mod0},
    "mod1": {"log_likelihood": log_mod1, "num_parameters": num_param_mod1},
    "mod2": {"log_likelihood": log_mod2, "num_parameters": num_param_mod2},
    #"mod2bis": {"log_likelihood": log_mod2bis, "num_parameters": num_param_mod2bis},
    "mod3": {"log_likelihood": log_mod3, "num_parameters": num_param_mod3},
    "nested": {"log_likelihood": log_nested, "num_parameters": num_param_nested},
    "cross": {"log_likelihood": log_cross, "num_parameters": num_param_cross},
}

# List of model names (in the order you want to test)
model_names = list(models.keys())

# Iterate over pairs of consecutive models
for i in range(1, len(model_names)):
    # Current and previous models
    current_model = models[model_names[i]]
    previous_model = models[model_names[i - 1]]
    
    # Extract log-likelihood and parameter counts
    LL_simple = previous_model["log_likelihood"]
    LL_complex = current_model["log_likelihood"]
    df = current_model["num_parameters"] - previous_model["num_parameters"]  # Degrees of freedom
    
    # Statistical test
    test_stat = -2 * (LL_simple - LL_complex)
    p_value = 1 - chi2.cdf(test_stat, df)
    
    # Print the results
    print(f"Comparing {model_names[i - 1]} vs {model_names[i]}:")
    print(f"  Test Statistic: {test_stat:.4f}")
    print(f"  P-value: {p_value:.4f}")
    
    # Interpretation
    if p_value < 0.05:
        print("  The complex model provides a significantly better fit.\n")
    else:
        print("  No significant improvement in the complex model.\n")
# Out:
# Comparing mod0 vs mod1:
#   Test Statistic: 889.3028
#   P-value: 0.0000
#   The complex model provides a significantly better fit.
#
# Comparing mod1 vs mod2:
#   Test Statistic: 156.1524
#   P-value: 0.0000
#   The complex model provides a significantly better fit.
#
# Comparing mod2 vs mod3:
#   Test Statistic: 44.6540
#   P-value: 0.0000
#   The complex model provides a significantly better fit.
#
# Comparing mod3 vs nested:
#   Test Statistic: 21.4417
#   P-value: 0.0000
#   The complex model provides a significantly better fit.
#
# Comparing nested vs cross:
#   Test Statistic: 2.3139
#   P-value: 0.3145
#   No significant improvement in the complex model.
