# %% [markdown]
# # Project Testing

# %% [markdown]
# ## Imports

# %%
from IPython.core.display_functions import display

from models.logit_lmpc12_model0 import results as res_mod0
from models.logit_lmpc12_model1 import results as res_mod1
from models.logit_lmpc12_model2 import results as res_mod2
from models.logit_lmpc12_model2bis import results as res_mod2bis
from models.logit_lmpc12_model3 import results as res_mod3
from models.logit_lmpc12_model4 import nests, nests_cross

# %% [markdown]
# Informations about the data [here](https://transp-or.epfl.ch/documents/technicalReports/CS_LPMC.pdf).

# %% [markdown]
# ## Base Model (Model 0)

# %%
print(res_mod0.print_general_statistics())
# Out:
# Number of estimated parameters:	5
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-6931.472
# Final log likelihood:	-4682.809
# Likelihood ratio test for the init. model:	4497.326
# Rho-square for the init. model:	0.324
# Rho-square-bar for the init. model:	0.324
# Akaike Information Criterion:	9375.618
# Bayesian Information Criterion:	9408.204
# Final gradient norm:	4.7836E-04
# Nbr of threads:	11

# %%
display(res_mod0.get_estimated_parameters())
# Out:
#                      Value  Rob. Std err  Rob. t-test  Rob. p-value
# beta_fare        -0.218834      0.016079   -13.609492  0.000000e+00
# beta_travel_time -4.912494      0.196880   -24.951709  0.000000e+00
# constant_2       -3.730648      0.109509   -34.066896  0.000000e+00
# constant_3       -0.330065      0.055250    -5.974008  2.314947e-09
# constant_4       -1.076784      0.080742   -13.336125  0.000000e+00

# %% [markdown]
# ## Alternative Specific Constant Model (Model 1)

# %%
print(res_mod1.print_general_statistics())
# Out:
# Number of estimated parameters:	8
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-6931.472
# Final log likelihood:	-4238.158
# Likelihood ratio test for the init. model:	5386.629
# Rho-square for the init. model:	0.389
# Rho-square-bar for the init. model:	0.387
# Akaike Information Criterion:	8492.315
# Bayesian Information Criterion:	8544.453
# Final gradient norm:	5.7638E-03
# Nbr of threads:	11

# %%
display(res_mod1.get_estimated_parameters())
# Out:
#                        Value  Rob. Std err  Rob. t-test  Rob. p-value
# beta_fare          -0.219858      0.019544   -11.249152           0.0
# beta_travel_time_1 -8.786268      0.388750   -22.601346           0.0
# beta_travel_time_2 -6.713743      0.611134   -10.985718           0.0
# beta_travel_time_3 -3.176268      0.247092   -12.854588           0.0
# beta_travel_time_4 -6.527898      0.399929   -16.322637           0.0
# constant_2         -4.545392      0.202842   -22.408566           0.0
# constant_3         -2.526224      0.131769   -19.171661           0.0
# constant_4         -2.007400      0.128415   -15.632118           0.0

# %% [markdown]
# ## Socioeconomic Model (Model 2)

# %% [markdown]
# ### Purpose of the Trip Model

# %%
print(res_mod2.print_general_statistics())
# Out:
# Number of estimated parameters:	24
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-6931.472
# Final log likelihood:	-4160.082
# Likelihood ratio test for the init. model:	5542.781
# Rho-square for the init. model:	0.4
# Rho-square-bar for the init. model:	0.396
# Akaike Information Criterion:	8368.163
# Bayesian Information Criterion:	8524.576
# Final gradient norm:	5.2884E-02
# Nbr of threads:	11

# %%
display(res_mod2.get_estimated_parameters())
# Out:
#                                             Value  Rob. Std err  Rob. t-test  \
# beta_fare                               -0.230202      0.020188   -11.402831
# beta_travel_time                        -7.479494      0.525645   -14.229184
# beta_travel_time_2                      -5.658437      0.753060    -7.513923
# beta_travel_time_2_employers business    0.171543      1.285356     0.133459
# beta_travel_time_2_home-based education -6.287193      2.239266    -2.807703
# beta_travel_time_2_home-based other     -3.710342      1.090988    -3.400899
# beta_travel_time_2_non-homebased other  -6.731647      1.914920    -3.515368
# beta_travel_time_3                      -2.714106      0.429126    -6.324734
# beta_travel_time_3_employers business    1.011008      0.753058     1.342536
# beta_travel_time_3_home-based education -0.203484      0.902001    -0.225592
# beta_travel_time_3_home-based other     -1.464841      0.583694    -2.509606
# beta_travel_time_3_non-homebased other  -1.248595      0.776110    -1.608785
# beta_travel_time_4                      -6.561956      0.722091    -9.087438
# beta_travel_time_4_employers business    2.782836      1.239662     2.244835
# beta_travel_time_4_home-based education -1.476971      1.976419    -0.747297
# beta_travel_time_4_home-based other     -1.030805      1.010992    -1.019597
# beta_travel_time_4_non-homebased other   0.113738      1.207687     0.094178
# beta_travel_time_employers business     -2.646056      0.946062    -2.796916
# beta_travel_time_home-based education   -1.267144      0.765267    -1.655820
# beta_travel_time_home-based other       -2.326780      0.542201    -4.291363
# beta_travel_time_non-homebased other    -1.269907      0.671956    -1.889867
# constant_2                              -4.309992      0.200713   -21.473417
# constant_3                              -2.556400      0.127232   -20.092498
# constant_4                              -2.098021      0.124002   -16.919266
#
#                                          Rob. p-value
# beta_fare                                0.000000e+00
# beta_travel_time                         0.000000e+00
# beta_travel_time_2                       5.728751e-14
# beta_travel_time_2_employers business    8.938301e-01
# beta_travel_time_2_home-based education  4.989624e-03
# beta_travel_time_2_home-based other      6.716455e-04
# beta_travel_time_2_non-homebased other   4.391453e-04
# beta_travel_time_3                       2.536689e-10
# beta_travel_time_3_employers business    1.794221e-01
# beta_travel_time_3_home-based education  8.215191e-01
# beta_travel_time_3_home-based other      1.208658e-02
# beta_travel_time_3_non-homebased other   1.076633e-01
# beta_travel_time_4                       0.000000e+00
# beta_travel_time_4_employers business    2.477874e-02
# beta_travel_time_4_home-based education  4.548845e-01
# beta_travel_time_4_home-based other      3.079196e-01
# beta_travel_time_4_non-homebased other   9.249676e-01
# beta_travel_time_employers business      5.159289e-03
# beta_travel_time_home-based education    9.775832e-02
# beta_travel_time_home-based other        1.775800e-05
# beta_travel_time_non-homebased other     5.877573e-02
# constant_2                               0.000000e+00
# constant_3                               0.000000e+00
# constant_4                               0.000000e+00

# %% [markdown]
# ### Gender Model

# %%
print(res_mod2bis.print_general_statistics())
# Out:
# Number of estimated parameters:	11
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-6931.472
# Final log likelihood:	-4238.158
# Likelihood ratio test for the init. model:	5386.629
# Rho-square for the init. model:	0.389
# Rho-square-bar for the init. model:	0.387
# Akaike Information Criterion:	8498.315
# Bayesian Information Criterion:	8570.004
# Final gradient norm:	5.7514E-03
# Nbr of threads:	11

# %%
display(res_mod2bis.get_estimated_parameters())
# Out:
#                        Value  Rob. Std err    Rob. t-test  Rob. p-value
# beta_fare          -0.219858  1.954443e-02  -1.124915e+01           0.0
# beta_travel_time   -8.786268  3.887498e-01  -2.260135e+01           0.0
# beta_travel_time_2 -6.713743  6.111337e-01  -1.098572e+01           0.0
# beta_travel_time_3 -3.176268  2.470922e-01  -1.285459e+01           0.0
# beta_travel_time_4 -6.527898  3.999291e-01  -1.632264e+01           0.0
# constant_2         -4.545392  2.028417e-01  -2.240857e+01           0.0
# constant_2_other    0.000000  9.245740e-17   0.000000e+00           1.0
# constant_3         -2.526224  1.317686e-01  -1.917166e+01           0.0
# constant_3_other    0.000000  0.000000e+00  1.797693e+308           0.0
# constant_4         -2.007400  1.284151e-01  -1.563212e+01           0.0
# constant_4_other    0.000000  0.000000e+00  1.797693e+308           0.0

# %% [markdown]
# ## Box Cox Model (Model 3)

# %%
print(res_mod3.print_general_statistics())
# Out:
# Number of estimated parameters:	25
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-6931.472
# Final log likelihood:	-4137.754
# Likelihood ratio test for the init. model:	5587.435
# Rho-square for the init. model:	0.403
# Rho-square-bar for the init. model:	0.399
# Akaike Information Criterion:	8325.509
# Bayesian Information Criterion:	8488.439
# Final gradient norm:	3.3844E-02
# Nbr of threads:	11

# %%
display(res_mod3.get_estimated_parameters())
# Out:
#                                              Value  Rob. Std err  Rob. t-test  \
# beta_fare                                -0.212231      0.019302   -10.995146
# beta_travel_time                         -8.773443      0.832585   -10.537589
# beta_travel_time_2                       -5.596998      0.511702   -10.938003
# beta_travel_time_2_employers business     0.824135      0.511689     1.610618
# beta_travel_time_2_home-based education   1.597938      0.418558     3.817719
# beta_travel_time_2_home-based other       0.660921      0.307785     2.147345
# beta_travel_time_2_non-homebased other    0.949492      0.405559     2.341191
# beta_travel_time_3                       -3.362903      0.330727   -10.168201
# beta_travel_time_3_employers business     1.061912      0.526614     2.016490
# beta_travel_time_3_home-based education   1.084810      0.403693     2.687215
# beta_travel_time_3_home-based other       0.351236      0.321817     1.091417
# beta_travel_time_3_non-homebased other    0.687775      0.357258     1.925150
# beta_travel_time_4                       -4.357223      0.388606   -11.212442
# beta_travel_time_4_employers business     0.168558      0.362371     0.465153
# beta_travel_time_4_home-based education   0.872468      0.291669     2.991295
# beta_travel_time_4_home-based other      -0.219549      0.238479    -0.920624
# beta_travel_time_4_non-homebased other   -0.358564      0.269699    -1.329499
# beta_travel_time_employers business      -5.210666      1.502864    -3.467158
# beta_travel_time_home-based education    -4.050489      1.142684    -3.544713
# beta_travel_time_home-based other        -1.778248      0.797666    -2.229315
# beta_travel_time_non-homebased other     -1.024081      0.945209    -1.083444
# constant_2                              -12.236767      0.435248   -28.114470
# constant_3                               -7.003633      0.297471   -23.543899
# constant_4                               -9.230158      0.369153   -25.003632
# lambda_boxcox                             0.522043      0.051422    10.152179
#
#                                          Rob. p-value
# beta_fare                                    0.000000
# beta_travel_time                             0.000000
# beta_travel_time_2                           0.000000
# beta_travel_time_2_employers business        0.107263
# beta_travel_time_2_home-based education      0.000135
# beta_travel_time_2_home-based other          0.031766
# beta_travel_time_2_non-homebased other       0.019222
# beta_travel_time_3                           0.000000
# beta_travel_time_3_employers business        0.043749
# beta_travel_time_3_home-based education      0.007205
# beta_travel_time_3_home-based other          0.275090
# beta_travel_time_3_non-homebased other       0.054211
# beta_travel_time_4                           0.000000
# beta_travel_time_4_employers business        0.641822
# beta_travel_time_4_home-based education      0.002778
# beta_travel_time_4_home-based other          0.357247
# beta_travel_time_4_non-homebased other       0.183683
# beta_travel_time_employers business          0.000526
# beta_travel_time_home-based education        0.000393
# beta_travel_time_home-based other            0.025793
# beta_travel_time_non-homebased other         0.278612
# constant_2                                   0.000000
# constant_3                                   0.000000
# constant_4                                   0.000000
# lambda_boxcox                                0.000000

# %% [markdown]
# ## Nested Model (Model 4)

# %%
from models.logit_lmpc12_model3 import V_boxcox as V
from models.logit_lmpc12_model3 import chosen_alternative as choice

# %%
logprob_nested = lognested(V, None,nests, choice)
biogeme_nested = bio.BIOGEME(database, logprob_nested)
biogeme_nested.modelName = 'nested_model'
results_nested = biogeme_nested.estimate(recycle=False)
print(results_nested.print_general_statistics())

# %%
display(results_nested.get_estimated_parameters())

# %% [markdown]
# ## Cross Nested Model (Model 4)

# %%
logprob_cnl = logcnl(V, None ,nests_cross, choice)
biogeme_cnl = bio.BIOGEME(database, logprob_cnl)
biogeme_cnl.modelName = 'cnl'
results_cross = biogeme_cnl.estimate(recycle=False)
print(results_cross.print_general_statistics())

# %%
display(results_cross.get_estimated_parameters())
