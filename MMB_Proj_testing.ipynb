# %% [markdown]
# # Project Testing

# %% [markdown]
# ## Imports

# %%
from IPython.core.display_functions import display

from models.logit_lmpc12_model0 import results as res_mod0
from models.logit_lmpc12_model1 import results as res_mod1
from models.logit_lmpc12_model2 import results as res_mod2
from models.logit_lmpc12_model2bis import results as res_mod2bis
from models.logit_lmpc12_model3 import results as res_mod3
# from models.logit_lmpc12_model4 import results as res_mod4

# %% [markdown]
# Informations about the data [here](https://transp-or.epfl.ch/documents/technicalReports/CS_LPMC.pdf).

# %% [markdown]
# ## Base Model (Model 0)

# %%
print(res_mod0.print_general_statistics())
# Out:
# Number of estimated parameters:	5
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-4944.754
# Final log likelihood:	-4944.754
# Likelihood ratio test for the init. model:	-0
# Rho-square for the init. model:	0
# Rho-square-bar for the init. model:	-0.00101
# Akaike Information Criterion:	9899.507
# Bayesian Information Criterion:	9932.093
# Final gradient norm:	9.3277E-04
# Nbr of threads:	4

# %%
display(res_mod0.get_estimated_parameters())
# Out:
#                      Value  Rob. Std err  Rob. t-test  Rob. p-value
# beta_fare        -0.095746      0.014123    -6.779637  1.204792e-11
# beta_travel_time -0.821380      0.033274   -24.685677  0.000000e+00
# constant_2       -1.732046      0.090821   -19.071058  0.000000e+00
# constant_3        1.013319      0.050913    19.902890  0.000000e+00
# constant_4        1.529033      0.060373    25.326636  0.000000e+00

# %% [markdown]
# ## Alternative Specific Constant Model (Model 1)

# %%
print(res_mod1.print_general_statistics())
# Out:
# Number of estimated parameters:	8
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-4727.49
# Final log likelihood:	-4727.49
# Likelihood ratio test for the init. model:	-0
# Rho-square for the init. model:	0
# Rho-square-bar for the init. model:	-0.00169
# Akaike Information Criterion:	9470.98
# Bayesian Information Criterion:	9523.118
# Final gradient norm:	3.7895E-02
# Nbr of threads:	4

# %%
display(res_mod1.get_estimated_parameters())
# Out:
#                        Value  Rob. Std err  Rob. t-test  Rob. p-value
# beta_fare          -0.145637      0.016964    -8.584861  0.000000e+00
# beta_travel_time_1 -1.313461      0.044899   -29.253806  0.000000e+00
# beta_travel_time_2 -1.557959      0.338910    -4.596971  4.286771e-06
# beta_travel_time_3  0.947296      0.140609     6.737075  1.616063e-11
# beta_travel_time_4 -0.528982      0.221740    -2.385599  1.705132e-02
# constant_2         -1.635756      0.128984   -12.681885  0.000000e+00
# constant_3          0.113626      0.074788     1.519307  1.286852e-01
# constant_4          1.428100      0.078484    18.196021  0.000000e+00

# %% [markdown]
# ## Socioeconomic Model (Model 2)

# %% [markdown]
# ### Purpose of the Trip Model

# %%
print(res_mod2.print_general_statistics())
# Out:
# Number of estimated parameters:	24
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-4645.691
# Final log likelihood:	-4645.691
# Likelihood ratio test for the init. model:	-0
# Rho-square for the init. model:	0
# Rho-square-bar for the init. model:	-0.00517
# Akaike Information Criterion:	9339.383
# Bayesian Information Criterion:	9495.796
# Final gradient norm:	6.6530E-02
# Nbr of threads:	4

# %%
display(res_mod2.get_estimated_parameters())
# Out:
#                                             Value  Rob. Std err  Rob. t-test  \
# beta_fare                               -0.167368      0.017390    -9.624555
# beta_travel_time                        -1.486244      0.141236   -10.523147
# beta_travel_time_2                      -0.623685      0.332730    -1.874445
# beta_travel_time_2_employers business   -1.728992      0.737576    -2.344156
# beta_travel_time_2_home-based education -4.564375      1.670077    -2.733032
# beta_travel_time_2_home-based other     -1.819184      0.578702    -3.143558
# beta_travel_time_2_non-homebased other  -6.280458      1.871707    -3.355470
# beta_travel_time_3                       1.725439      0.207231     8.326144
# beta_travel_time_3_employers business   -1.010118      0.296264    -3.409523
# beta_travel_time_3_home-based education -0.229795      0.352649    -0.651625
# beta_travel_time_3_home-based other     -0.831939      0.208344    -3.993112
# beta_travel_time_3_non-homebased other  -1.196950      0.292564    -4.091239
# beta_travel_time_4                      -0.419346      0.287591    -1.458133
# beta_travel_time_4_employers business   -0.344985      0.503211    -0.685568
# beta_travel_time_4_home-based education -0.034237      0.692271    -0.049457
# beta_travel_time_4_home-based other      1.142014      0.391143     2.919680
# beta_travel_time_4_non-homebased other  -0.330306      0.470691    -0.701747
# beta_travel_time_employers business     -1.079374      0.365691    -2.951598
# beta_travel_time_home-based education    0.741487      0.208763     3.551817
# beta_travel_time_home-based other        0.208226      0.162940     1.277931
# beta_travel_time_non-homebased other     0.310448      0.188938     1.643116
# constant_2                              -1.413303      0.133423   -10.592648
# constant_3                               0.105130      0.076473     1.374741
# constant_4                               1.341305      0.082087    16.340107
#
#                                          Rob. p-value
# beta_fare                                    0.000000
# beta_travel_time                             0.000000
# beta_travel_time_2                           0.060869
# beta_travel_time_2_employers business        0.019070
# beta_travel_time_2_home-based education      0.006275
# beta_travel_time_2_home-based other          0.001669
# beta_travel_time_2_non-homebased other       0.000792
# beta_travel_time_3                           0.000000
# beta_travel_time_3_employers business        0.000651
# beta_travel_time_3_home-based education      0.514643
# beta_travel_time_3_home-based other          0.000065
# beta_travel_time_3_non-homebased other       0.000043
# beta_travel_time_4                           0.144804
# beta_travel_time_4_employers business        0.492986
# beta_travel_time_4_home-based education      0.960555
# beta_travel_time_4_home-based other          0.003504
# beta_travel_time_4_non-homebased other       0.482837
# beta_travel_time_employers business          0.003161
# beta_travel_time_home-based education        0.000383
# beta_travel_time_home-based other            0.201274
# beta_travel_time_non-homebased other         0.100359
# constant_2                                   0.000000
# constant_3                                   0.169212
# constant_4                                   0.000000

# %% [markdown]
# ### Gender Model

# %%
print(res_mod2bis.print_general_statistics())
# Out:
# Number of estimated parameters:	11
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-4727.49
# Final log likelihood:	-4727.49
# Likelihood ratio test for the init. model:	-0
# Rho-square for the init. model:	0
# Rho-square-bar for the init. model:	-0.00233
# Akaike Information Criterion:	9476.98
# Bayesian Information Criterion:	9548.669
# Final gradient norm:	3.7892E-02
# Nbr of threads:	4

# %%
display(res_mod2bis.get_estimated_parameters())
# Out:
#                        Value   Rob. Std err    Rob. t-test  Rob. p-value
# beta_fare          -0.145637   1.696435e-02  -8.584861e+00  0.000000e+00
# beta_travel_time   -1.313461   4.489880e-02  -2.925381e+01  0.000000e+00
# beta_travel_time_2 -1.557959   3.389099e-01  -4.596971e+00  4.286771e-06
# beta_travel_time_3  0.947296   1.406094e-01   6.737075e+00  1.616063e-11
# beta_travel_time_4 -0.528982   2.217398e-01  -2.385599e+00  1.705132e-02
# constant_2         -1.635756   1.289837e-01  -1.268188e+01  0.000000e+00
# constant_2_other    0.000000  1.797693e+308   0.000000e+00  1.000000e+00
# constant_3          0.113626   7.478781e-02   1.519307e+00  1.286852e-01
# constant_3_other    0.000000   0.000000e+00  1.797693e+308  0.000000e+00
# constant_4          1.428100   7.848422e-02   1.819602e+01  0.000000e+00
# constant_4_other    0.000000   0.000000e+00  1.797693e+308  0.000000e+00

# %% [markdown]
# ## Box Cox Model (Model 3)

# %%
print(res_mod3.print_general_statistics())
# Out:
# Number of estimated parameters:	25
# Sample size:	5000
# Excluded observations:	0
# Init log likelihood:	-4468.053
# Final log likelihood:	-4468.053
# Likelihood ratio test for the init. model:	-0
# Rho-square for the init. model:	0
# Rho-square-bar for the init. model:	-0.0056
# Akaike Information Criterion:	8986.105
# Bayesian Information Criterion:	9149.035
# Final gradient norm:	2.2421E-02
# Nbr of threads:	4

# %%
display(res_mod3.get_estimated_parameters())
# Out:
#                                             Value  Rob. Std err  Rob. t-test  \
# beta_fare                               -0.231674      0.016320   -14.195630
# beta_travel_time                        -1.047685      0.105101    -9.968359
# beta_travel_time_2                      -0.053375      0.032252    -1.654953
# beta_travel_time_2_employers business   -0.071348      0.076799    -0.929029
# beta_travel_time_2_home-based education  0.141086      0.054834     2.572967
# beta_travel_time_2_home-based other      0.106404      0.039798     2.673574
# beta_travel_time_2_non-homebased other   0.147135      0.059774     2.461526
# beta_travel_time_3                       0.299965      0.095701     3.134405
# beta_travel_time_3_employers business    0.065988      0.141326     0.466925
# beta_travel_time_3_home-based education  0.370544      0.086973     4.260449
# beta_travel_time_3_home-based other      0.231736      0.075222     3.080684
# beta_travel_time_3_non-homebased other   0.303936      0.086368     3.519065
# beta_travel_time_4                       0.088742      0.066526     1.333955
# beta_travel_time_4_employers business   -0.022950      0.080618    -0.284682
# beta_travel_time_4_home-based education  0.145666      0.049913     2.918381
# beta_travel_time_4_home-based other      0.051599      0.049920     1.033634
# beta_travel_time_4_non-homebased other   0.082670      0.050305     1.643378
# beta_travel_time_employers business     -0.509316      0.226804    -2.245621
# beta_travel_time_home-based education    0.372805      0.160780     2.318737
# beta_travel_time_home-based other        0.164297      0.127757     1.286014
# beta_travel_time_non-homebased other     0.349663      0.148010     2.362423
# constant_2                              -1.573398      0.121116   -12.990833
# constant_3                               2.103410      0.098129    21.435090
# constant_4                               2.581868      0.119874    21.538254
# lambda_boxcox                           -0.857969      0.089884    -9.545246
#
#                                          Rob. p-value
# beta_fare                                    0.000000
# beta_travel_time                             0.000000
# beta_travel_time_2                           0.097934
# beta_travel_time_2_employers business        0.352874
# beta_travel_time_2_home-based education      0.010083
# beta_travel_time_2_home-based other          0.007505
# beta_travel_time_2_non-homebased other       0.013835
# beta_travel_time_3                           0.001722
# beta_travel_time_3_employers business        0.640553
# beta_travel_time_3_home-based education      0.000020
# beta_travel_time_3_home-based other          0.002065
# beta_travel_time_3_non-homebased other       0.000433
# beta_travel_time_4                           0.182219
# beta_travel_time_4_employers business        0.775888
# beta_travel_time_4_home-based education      0.003519
# beta_travel_time_4_home-based other          0.301307
# beta_travel_time_4_non-homebased other       0.100305
# beta_travel_time_employers business          0.024728
# beta_travel_time_home-based education        0.020409
# beta_travel_time_home-based other            0.198438
# beta_travel_time_non-homebased other         0.018156
# constant_2                                   0.000000
# constant_3                                   0.000000
# constant_4                                   0.000000
# lambda_boxcox                                0.000000

# %% [markdown]
# ## Cross Nested Model (Model 4)
